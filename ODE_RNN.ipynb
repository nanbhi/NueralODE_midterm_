# %% [markdown]
# ### 모델 돌리는 시간상 40 iteration.
# * RK4 method 사용
# * 30번 반복 정도에 converge하기에 40번 만 돌려서 학습

# %%
#%mkdir data
#%mkdir data/person

#!wget --no-check-certificate https://archive.ics.uci.edu/ml/machine-learning-databases/00196/ConfLongDemo_JSI.txt
#%mv ConfLongDemo_JSI.txt data/person/

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/GraduateSchool/NeuralODE/midterm_assignment
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/GraduateSchool/NeuralODE/midterm_assignment

# %%
# Copyright 2021 The ODE-LSTM Authors. All Rights Reserved.
import os
import tensorflow as tf
import argparse
from irregular_sampled_datasets import PersonData
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = PersonData()
# Out:
# all_x.shape:  (9711, 32, 7)
# all_t.shape:  (9711, 32, 1)
# all_y.shape:  (9711, 32)
# Total number of sequences: 9711
# train_x.shape:  (7769, 32, 7)
# train_t.shape:  (7769, 32, 1)
# train_y.shape:  (7769, 32)
# Total number of train sequences: 7769
# Total number of test  sequences: 1942

# %%
class CTRNNCell(tf.keras.layers.Layer):
    def __init__(self, units, method, num_unfolds=None, tau=1, **kwargs):
        self.fixed_step_methods = {
            "euler": self.euler,
            "heun": self.heun,
            "rk4": self.rk4,
        }
        allowed_methods = ["euler", "heun", "rk4", "dopri5"]
        if not method in allowed_methods:
            raise ValueError(
                "Unknown ODE solver '{}', expected one of '{}'".format(
                    method, allowed_methods
                )
            )
        if method in self.fixed_step_methods.keys() and num_unfolds is None:
            raise ValueError(
                "Fixed-step ODE solver requires argument 'num_unfolds' to be specified!"
            )
        self.units = units
        self.state_size = units
        self.num_unfolds = num_unfolds
        self.method = method
        self.tau = tau
        super(CTRNNCell, self).__init__(**kwargs)

    def build(self, input_shape):
        input_dim = input_shape[-1] - 1 # time column 제거
        # if isinstance(input_shape[0], tuple):
        #     # Nested tuple
        #     input_dim = input_shape[0][-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units), initializer="glorot_uniform", name="kernel"
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units),
            initializer="orthogonal",
            name="recurrent_kernel",
        )
        self.bias = self.add_weight(
            shape=(self.units,), initializer=tf.keras.initializers.Zeros(), name="bias"
        )
        self.scale = self.add_weight(
            shape=(self.units,),
            initializer=tf.keras.initializers.Constant(1.0),
            name="scale",
        )
        if self.method == "dopri5":
            # Only load tfp packge if it is really needed
            import tensorflow_probability as tfp

            # We don't need the most precise solver to speed up training
            self.solver = tfp.math.ode.DormandPrince(
                rtol=0.01,
                atol=1e-04,
                first_step_size=0.01,
                safety_factor=0.8,
                min_step_size_factor=0.1,
                max_step_size_factor=10.0,
                max_num_steps=None,
                make_adjoint_solver_fn=None,
                validate_args=False,
                name="dormand_prince",
            )
        self.built = True

    def call(self, inputs, states):
        hidden_state = states[0]
        elapsed = 1.0
        # if (isinstance(inputs, tuple) or isinstance(inputs, list)) and len(inputs) > 1:
        #     elapsed = inputs[1]
        #     inputs = inputs[0]
        elapsed = inputs[:,7:]
        inputs = inputs[:, :-1]

        if self.method == "dopri5":
            # Only load tfp packge if it is really needed
            import tensorflow_probability as tfp

            if not type(elapsed) == float:
                batch_dim = tf.shape(elapsed)[0]
                elapsed = tf.reshape(elapsed, [batch_dim])

                idx = tf.argsort(elapsed)
                solution_times = tf.gather(elapsed, idx)
            else:
                solution_times = elapsed
            hidden_state = states[0]
            res = self.solver.solve(
                ode_fn=self.dfdt_wrapped,
                initial_time=0,
                initial_state=hidden_state,
                solution_times=solution_times,  # tfp.math.ode.ChosenBySolver(elapsed),
                constants={"input": inputs},
            )
            if not type(elapsed) == float:
                i2 = tf.stack([idx, tf.range(batch_dim)], axis=1)
                hidden_state = tf.gather_nd(res.states, i2)
            else:
                hidden_state = res.states[-1]
        else:
            delta_t = elapsed / self.num_unfolds
            method = self.fixed_step_methods[self.method]
            for i in range(self.num_unfolds):
                hidden_state = method(inputs, hidden_state, delta_t)
        return hidden_state, [hidden_state]

    def dfdt_wrapped(self, t, y, **constants):
        inputs = constants["input"]
        hidden_state = y
        return self.dfdt(inputs, hidden_state)

    def dfdt(self, inputs, hidden_state):
        h_in = tf.matmul(inputs, self.kernel)
        h_rec = tf.matmul(hidden_state, self.recurrent_kernel)
        dh_in = self.scale * tf.nn.tanh(h_in + h_rec + self.bias)
        if self.tau > 0:
            dh = dh_in - hidden_state * self.tau
        else:
            dh = dh_in
        return dh

    def euler(self, inputs, hidden_state, delta_t):
        dy = self.dfdt(inputs, hidden_state)
        return hidden_state + delta_t * dy

    def heun(self, inputs, hidden_state, delta_t):
        k1 = self.dfdt(inputs, hidden_state)
        k2 = self.dfdt(inputs, hidden_state + delta_t * k1)
        return hidden_state + delta_t * 0.5 * (k1 + k2)

    def rk4(self, inputs, hidden_state, delta_t):
        k1 = self.dfdt(inputs, hidden_state)
        k2 = self.dfdt(inputs, hidden_state + k1 * delta_t * 0.5)
        k3 = self.dfdt(inputs, hidden_state + k2 * delta_t * 0.5)
        k4 = self.dfdt(inputs, hidden_state + k3 * delta_t)

        return hidden_state + delta_t * (k1 + 2 * k2 + 2 * k3 + k4) / 6.0

# %%
def train_model():
    pixel_input = tf.keras.Input(shape=(data.seq_len, data.feature_size), name="features")
    time_input = tf.keras.Input(shape=(data.seq_len, 1), name="time")

    # concatLayer 정의
    # 저자가 제공하는 lstm 코드에서는 call 부분에서 concat을 진행하였지만 현재 tensorflow rnn이 tuple 형태의 multi-input이 안되어 미리 병합하는 layer를 정의한다.
    class concatLayer(tf.keras.layers.Layer):
        def call(self, x, y):
            concat = tf.concat([x, y], axis=-1)  # (None, seq_len, feature_size + 1)
            return concat  # (None, seq_len, 8)

    # 입력 병합
    inputs = concatLayer()(pixel_input, time_input)
    rnn = tf.keras.layers.RNN(CTRNNCell(64, method= "rk4", num_unfolds=10), return_sequences=True)
    dense_layer = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(data.num_classes))

    #output_states = rnn((pixel_input, time_input))
    output_states = rnn(inputs)
    y = dense_layer(output_states)

    model = tf.keras.Model(inputs=[pixel_input, time_input], outputs=[y])
    model.compile(
        optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.01),
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
    )


    # 모델 훈련 및 평가
    hist = model.fit(
        x=(data.train_x, data.train_t),
        y=data.train_y,
        batch_size=128,
        epochs=40,
        validation_data=((data.test_x, data.test_t), data.test_y),
    )
    _, best_test_acc = model.evaluate(
        x=(data.test_x, data.test_t), y=data.test_y, verbose=2
    )

    return model, hist,best_test_acc

# %%
model_1, hist_1, best_test_acc_1 = train_model()
print("1 끝")
model_2, hist_2, best_test_acc_2 = train_model()
print("2 끝")
model_3, hist_3, best_test_acc_3 = train_model()
print("3 끝")
model_4, hist_4, best_test_acc_4 = train_model()
print("4 끝")
model_5, hist_5, best_test_acc_5 = train_model()
print("5 끝")
# Out:
# Epoch 1/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 315ms/step - loss: 1.7888 - sparse_categorical_accuracy: 0.3350 - val_loss: 1.4976 - val_sparse_categorical_accuracy: 0.3857
# Epoch 2/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 1.4284 - sparse_categorical_accuracy: 0.4423 - val_loss: 1.1612 - val_sparse_categorical_accuracy: 0.5679
# Epoch 3/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 1.2014 - sparse_categorical_accuracy: 0.5280 - val_loss: 1.0903 - val_sparse_categorical_accuracy: 0.5870
# Epoch 4/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 1.1103 - sparse_categorical_accuracy: 0.5650 - val_loss: 1.1668 - val_sparse_categorical_accuracy: 0.5765
# Epoch 5/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 1.0595 - sparse_categorical_accuracy: 0.5856 - val_loss: 0.9684 - val_sparse_categorical_accuracy: 0.6250
# Epoch 6/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.9668 - sparse_categorical_accuracy: 0.6270 - val_loss: 0.9032 - val_sparse_categorical_accuracy: 0.6170
# Epoch 7/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.9459 - sparse_categorical_accuracy: 0.6414 - val_loss: 0.8809 - val_sparse_categorical_accuracy: 0.6838
# Epoch 8/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.8722 - sparse_categorical_accuracy: 0.6700 - val_loss: 0.8385 - val_sparse_categorical_accuracy: 0.6845
# Epoch 9/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.8524 - sparse_categorical_accuracy: 0.6828 - val_loss: 0.8261 - val_sparse_categorical_accuracy: 0.6834
# Epoch 10/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.8226 - sparse_categorical_accuracy: 0.6917 - val_loss: 0.7824 - val_sparse_categorical_accuracy: 0.7015
# Epoch 11/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.7947 - sparse_categorical_accuracy: 0.7047 - val_loss: 0.8211 - val_sparse_categorical_accuracy: 0.6930
# Epoch 12/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.7448 - sparse_categorical_accuracy: 0.7240 - val_loss: 0.7340 - val_sparse_categorical_accuracy: 0.7067
# Epoch 13/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.7412 - sparse_categorical_accuracy: 0.7249 - val_loss: 0.6927 - val_sparse_categorical_accuracy: 0.7538
# Epoch 14/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.7004 - sparse_categorical_accuracy: 0.7439 - val_loss: 0.7343 - val_sparse_categorical_accuracy: 0.7327
# Epoch 15/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6781 - sparse_categorical_accuracy: 0.7548 - val_loss: 0.6497 - val_sparse_categorical_accuracy: 0.7673
# Epoch 16/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.6754 - sparse_categorical_accuracy: 0.7484 - val_loss: 0.7503 - val_sparse_categorical_accuracy: 0.7225
# Epoch 17/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6540 - sparse_categorical_accuracy: 0.7596 - val_loss: 0.6586 - val_sparse_categorical_accuracy: 0.7444
# Epoch 18/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - loss: 0.6311 - sparse_categorical_accuracy: 0.7665 - val_loss: 0.6362 - val_sparse_categorical_accuracy: 0.7665
# Epoch 19/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.6381 - sparse_categorical_accuracy: 0.7666 - val_loss: 0.7454 - val_sparse_categorical_accuracy: 0.7126
# Epoch 20/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6105 - sparse_categorical_accuracy: 0.7755 - val_loss: 0.6891 - val_sparse_categorical_accuracy: 0.7508
# Epoch 21/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.5984 - sparse_categorical_accuracy: 0.7801 - val_loss: 0.6312 - val_sparse_categorical_accuracy: 0.7756
# Epoch 22/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5987 - sparse_categorical_accuracy: 0.7830 - val_loss: 0.5892 - val_sparse_categorical_accuracy: 0.7880
# Epoch 23/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.5902 - sparse_categorical_accuracy: 0.7832 - val_loss: 0.5509 - val_sparse_categorical_accuracy: 0.8043
# Epoch 24/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5710 - sparse_categorical_accuracy: 0.7947 - val_loss: 0.6981 - val_sparse_categorical_accuracy: 0.7447
# Epoch 25/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5779 - sparse_categorical_accuracy: 0.7933 - val_loss: 0.6075 - val_sparse_categorical_accuracy: 0.7788
# Epoch 26/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5590 - sparse_categorical_accuracy: 0.7994 - val_loss: 0.5658 - val_sparse_categorical_accuracy: 0.7993
# Epoch 27/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - loss: 0.5616 - sparse_categorical_accuracy: 0.7930 - val_loss: 0.5370 - val_sparse_categorical_accuracy: 0.8069
# Epoch 28/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5318 - sparse_categorical_accuracy: 0.8068 - val_loss: 0.5441 - val_sparse_categorical_accuracy: 0.8056
# Epoch 29/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.5305 - sparse_categorical_accuracy: 0.8119 - val_loss: 0.6723 - val_sparse_categorical_accuracy: 0.7694
# Epoch 30/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5249 - sparse_categorical_accuracy: 0.8103 - val_loss: 0.5499 - val_sparse_categorical_accuracy: 0.8025
# Epoch 31/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5056 - sparse_categorical_accuracy: 0.8194 - val_loss: 0.5748 - val_sparse_categorical_accuracy: 0.7961
# Epoch 32/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5220 - sparse_categorical_accuracy: 0.8108 - val_loss: 0.5262 - val_sparse_categorical_accuracy: 0.8123
# Epoch 33/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.4922 - sparse_categorical_accuracy: 0.8251 - val_loss: 0.5477 - val_sparse_categorical_accuracy: 0.8091
# Epoch 34/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.4991 - sparse_categorical_accuracy: 0.8234 - val_loss: 0.6037 - val_sparse_categorical_accuracy: 0.7839
# Epoch 35/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5076 - sparse_categorical_accuracy: 0.8182 - val_loss: 0.5150 - val_sparse_categorical_accuracy: 0.8135
# Epoch 36/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - loss: 0.4931 - sparse_categorical_accuracy: 0.8208 - val_loss: 0.4883 - val_sparse_categorical_accuracy: 0.8216
# Epoch 37/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.4839 - sparse_categorical_accuracy: 0.8238 - val_loss: 0.5418 - val_sparse_categorical_accuracy: 0.8092
# Epoch 38/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.4764 - sparse_categorical_accuracy: 0.8292 - val_loss: 0.5331 - val_sparse_categorical_accuracy: 0.8070
# Epoch 39/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.4848 - sparse_categorical_accuracy: 0.8261 - val_loss: 0.5103 - val_sparse_categorical_accuracy: 0.8180
# Epoch 40/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.4937 - sparse_categorical_accuracy: 0.8219 - val_loss: 0.5499 - val_sparse_categorical_accuracy: 0.8015
# 61/61 - 3s - 55ms/step - loss: 0.5499 - sparse_categorical_accuracy: 0.8015
# 1 끝
# Epoch 1/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 46s 334ms/step - loss: 1.7508 - sparse_categorical_accuracy: 0.3420 - val_loss: 1.3291 - val_sparse_categorical_accuracy: 0.4905
# Epoch 2/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 1.3393 - sparse_categorical_accuracy: 0.4895 - val_loss: 1.0823 - val_sparse_categorical_accuracy: 0.5840
# Epoch 3/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 1.1604 - sparse_categorical_accuracy: 0.5320 - val_loss: 1.1566 - val_sparse_categorical_accuracy: 0.5450
# Epoch 4/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 1.0843 - sparse_categorical_accuracy: 0.5671 - val_loss: 1.0282 - val_sparse_categorical_accuracy: 0.5702
# Epoch 5/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 1.0400 - sparse_categorical_accuracy: 0.5905 - val_loss: 0.9446 - val_sparse_categorical_accuracy: 0.6553
# Epoch 6/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.9853 - sparse_categorical_accuracy: 0.6163 - val_loss: 1.4632 - val_sparse_categorical_accuracy: 0.4773
# Epoch 7/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.9778 - sparse_categorical_accuracy: 0.6247 - val_loss: 0.8632 - val_sparse_categorical_accuracy: 0.6791
# Epoch 8/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.9057 - sparse_categorical_accuracy: 0.6542 - val_loss: 0.9178 - val_sparse_categorical_accuracy: 0.6522
# Epoch 9/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.8852 - sparse_categorical_accuracy: 0.6666 - val_loss: 0.8965 - val_sparse_categorical_accuracy: 0.6494
# Epoch 10/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.8379 - sparse_categorical_accuracy: 0.6875 - val_loss: 0.7929 - val_sparse_categorical_accuracy: 0.7110
# Epoch 11/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.8096 - sparse_categorical_accuracy: 0.6962 - val_loss: 0.8465 - val_sparse_categorical_accuracy: 0.6865
# Epoch 12/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.7692 - sparse_categorical_accuracy: 0.7171 - val_loss: 0.8257 - val_sparse_categorical_accuracy: 0.6780
# Epoch 13/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.7579 - sparse_categorical_accuracy: 0.7188 - val_loss: 0.7553 - val_sparse_categorical_accuracy: 0.7145
# Epoch 14/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.7433 - sparse_categorical_accuracy: 0.7246 - val_loss: 0.7204 - val_sparse_categorical_accuracy: 0.7382
# Epoch 15/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - loss: 0.6938 - sparse_categorical_accuracy: 0.7400 - val_loss: 0.7621 - val_sparse_categorical_accuracy: 0.7089
# Epoch 16/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6858 - sparse_categorical_accuracy: 0.7524 - val_loss: 0.6819 - val_sparse_categorical_accuracy: 0.7506
# Epoch 17/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6687 - sparse_categorical_accuracy: 0.7523 - val_loss: 0.6930 - val_sparse_categorical_accuracy: 0.7541
# Epoch 18/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6630 - sparse_categorical_accuracy: 0.7602 - val_loss: 0.7595 - val_sparse_categorical_accuracy: 0.7097
# Epoch 19/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6395 - sparse_categorical_accuracy: 0.7637 - val_loss: 0.6294 - val_sparse_categorical_accuracy: 0.7716
# Epoch 20/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6154 - sparse_categorical_accuracy: 0.7748 - val_loss: 0.6026 - val_sparse_categorical_accuracy: 0.7884
# Epoch 21/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6268 - sparse_categorical_accuracy: 0.7710 - val_loss: 0.6333 - val_sparse_categorical_accuracy: 0.7649
# Epoch 22/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6072 - sparse_categorical_accuracy: 0.7771 - val_loss: 0.7160 - val_sparse_categorical_accuracy: 0.7294
# Epoch 23/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6022 - sparse_categorical_accuracy: 0.7802 - val_loss: 0.6744 - val_sparse_categorical_accuracy: 0.7314
# Epoch 24/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5827 - sparse_categorical_accuracy: 0.7861 - val_loss: 0.5927 - val_sparse_categorical_accuracy: 0.7824
# Epoch 25/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5639 - sparse_categorical_accuracy: 0.7960 - val_loss: 0.6098 - val_sparse_categorical_accuracy: 0.7806
# Epoch 26/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5444 - sparse_categorical_accuracy: 0.8041 - val_loss: 0.6138 - val_sparse_categorical_accuracy: 0.7745
# Epoch 27/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5380 - sparse_categorical_accuracy: 0.8046 - val_loss: 0.5460 - val_sparse_categorical_accuracy: 0.8028
# Epoch 28/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - loss: 0.5393 - sparse_categorical_accuracy: 0.8012 - val_loss: 0.6136 - val_sparse_categorical_accuracy: 0.7735
# Epoch 29/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5500 - sparse_categorical_accuracy: 0.8014 - val_loss: 0.5978 - val_sparse_categorical_accuracy: 0.7753
# Epoch 30/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5396 - sparse_categorical_accuracy: 0.8029 - val_loss: 0.5811 - val_sparse_categorical_accuracy: 0.7831
# Epoch 31/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.5274 - sparse_categorical_accuracy: 0.8075 - val_loss: 0.5517 - val_sparse_categorical_accuracy: 0.8057
# Epoch 32/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5010 - sparse_categorical_accuracy: 0.8210 - val_loss: 0.6025 - val_sparse_categorical_accuracy: 0.7896
# Epoch 33/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - loss: 0.5114 - sparse_categorical_accuracy: 0.8140 - val_loss: 0.5041 - val_sparse_categorical_accuracy: 0.8224
# Epoch 34/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.4945 - sparse_categorical_accuracy: 0.8227 - val_loss: 0.5211 - val_sparse_categorical_accuracy: 0.8107
# Epoch 35/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.4904 - sparse_categorical_accuracy: 0.8220 - val_loss: 0.5110 - val_sparse_categorical_accuracy: 0.8192
# Epoch 36/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.5025 - sparse_categorical_accuracy: 0.8172 - val_loss: 0.5117 - val_sparse_categorical_accuracy: 0.8179
# Epoch 37/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.4956 - sparse_categorical_accuracy: 0.8192 - val_loss: 0.5224 - val_sparse_categorical_accuracy: 0.8108
# Epoch 38/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.4914 - sparse_categorical_accuracy: 0.8225 - val_loss: 0.5215 - val_sparse_categorical_accuracy: 0.8110
# Epoch 39/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.4901 - sparse_categorical_accuracy: 0.8208 - val_loss: 0.5021 - val_sparse_categorical_accuracy: 0.8205
# Epoch 40/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.4813 - sparse_categorical_accuracy: 0.8267 - val_loss: 0.4909 - val_sparse_categorical_accuracy: 0.8268
# 61/61 - 3s - 46ms/step - loss: 0.4909 - sparse_categorical_accuracy: 0.8268
# 2 끝
# Epoch 1/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 327ms/step - loss: 1.8093 - sparse_categorical_accuracy: 0.3218 - val_loss: 1.3800 - val_sparse_categorical_accuracy: 0.4907
# Epoch 2/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 1.3765 - sparse_categorical_accuracy: 0.4643 - val_loss: 1.1847 - val_sparse_categorical_accuracy: 0.5417
# Epoch 3/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 1.1770 - sparse_categorical_accuracy: 0.5457 - val_loss: 1.0355 - val_sparse_categorical_accuracy: 0.6042
# Epoch 4/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 1.0847 - sparse_categorical_accuracy: 0.5712 - val_loss: 1.0377 - val_sparse_categorical_accuracy: 0.5941
# Epoch 5/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 1.0141 - sparse_categorical_accuracy: 0.6032 - val_loss: 0.9900 - val_sparse_categorical_accuracy: 0.6252
# Epoch 6/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.9696 - sparse_categorical_accuracy: 0.6239 - val_loss: 0.9357 - val_sparse_categorical_accuracy: 0.6416
# Epoch 7/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.9488 - sparse_categorical_accuracy: 0.6351 - val_loss: 0.8590 - val_sparse_categorical_accuracy: 0.6765
# Epoch 8/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.9025 - sparse_categorical_accuracy: 0.6539 - val_loss: 0.8922 - val_sparse_categorical_accuracy: 0.6622
# Epoch 9/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.8546 - sparse_categorical_accuracy: 0.6785 - val_loss: 0.7879 - val_sparse_categorical_accuracy: 0.7231
# Epoch 10/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.8426 - sparse_categorical_accuracy: 0.6822 - val_loss: 0.7753 - val_sparse_categorical_accuracy: 0.7158
# Epoch 11/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.7780 - sparse_categorical_accuracy: 0.7104 - val_loss: 0.7201 - val_sparse_categorical_accuracy: 0.7394
# Epoch 12/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.7769 - sparse_categorical_accuracy: 0.7068 - val_loss: 0.7477 - val_sparse_categorical_accuracy: 0.7327
# Epoch 13/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - loss: 0.7353 - sparse_categorical_accuracy: 0.7309 - val_loss: 0.6949 - val_sparse_categorical_accuracy: 0.7556
# Epoch 14/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.7174 - sparse_categorical_accuracy: 0.7333 - val_loss: 0.6864 - val_sparse_categorical_accuracy: 0.7513
# Epoch 15/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.6935 - sparse_categorical_accuracy: 0.7446 - val_loss: 0.6827 - val_sparse_categorical_accuracy: 0.7484
# Epoch 16/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.6912 - sparse_categorical_accuracy: 0.7421 - val_loss: 0.6446 - val_sparse_categorical_accuracy: 0.7663
# Epoch 17/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6609 - sparse_categorical_accuracy: 0.7571 - val_loss: 0.6592 - val_sparse_categorical_accuracy: 0.7626
# Epoch 18/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.6633 - sparse_categorical_accuracy: 0.7570 - val_loss: 0.9446 - val_sparse_categorical_accuracy: 0.6725
# Epoch 19/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6613 - sparse_categorical_accuracy: 0.7584 - val_loss: 0.6570 - val_sparse_categorical_accuracy: 0.7529
# Epoch 20/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6489 - sparse_categorical_accuracy: 0.7609 - val_loss: 0.6129 - val_sparse_categorical_accuracy: 0.7798
# Epoch 21/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6478 - sparse_categorical_accuracy: 0.7613 - val_loss: 0.6129 - val_sparse_categorical_accuracy: 0.7722
# Epoch 22/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6178 - sparse_categorical_accuracy: 0.7673 - val_loss: 0.6023 - val_sparse_categorical_accuracy: 0.7802
# Epoch 23/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5967 - sparse_categorical_accuracy: 0.7832 - val_loss: 0.6139 - val_sparse_categorical_accuracy: 0.7731
# Epoch 24/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5843 - sparse_categorical_accuracy: 0.7845 - val_loss: 0.6053 - val_sparse_categorical_accuracy: 0.7730
# Epoch 25/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.5840 - sparse_categorical_accuracy: 0.7865 - val_loss: 0.5728 - val_sparse_categorical_accuracy: 0.7928
# Epoch 26/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5690 - sparse_categorical_accuracy: 0.7961 - val_loss: 0.6124 - val_sparse_categorical_accuracy: 0.7714
# Epoch 27/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5568 - sparse_categorical_accuracy: 0.7959 - val_loss: 0.5872 - val_sparse_categorical_accuracy: 0.7874
# Epoch 28/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.5417 - sparse_categorical_accuracy: 0.8003 - val_loss: 0.5398 - val_sparse_categorical_accuracy: 0.8041
# Epoch 29/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.5298 - sparse_categorical_accuracy: 0.8077 - val_loss: 0.7405 - val_sparse_categorical_accuracy: 0.7164
# Epoch 30/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5484 - sparse_categorical_accuracy: 0.7984 - val_loss: 0.6274 - val_sparse_categorical_accuracy: 0.7815
# Epoch 31/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5144 - sparse_categorical_accuracy: 0.8113 - val_loss: 0.5255 - val_sparse_categorical_accuracy: 0.8099
# Epoch 32/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5148 - sparse_categorical_accuracy: 0.8181 - val_loss: 0.5245 - val_sparse_categorical_accuracy: 0.8097
# Epoch 33/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5035 - sparse_categorical_accuracy: 0.8165 - val_loss: 0.5289 - val_sparse_categorical_accuracy: 0.8102
# Epoch 34/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.5037 - sparse_categorical_accuracy: 0.8165 - val_loss: 0.5333 - val_sparse_categorical_accuracy: 0.8049
# Epoch 35/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5099 - sparse_categorical_accuracy: 0.8145 - val_loss: 0.5127 - val_sparse_categorical_accuracy: 0.8127
# Epoch 36/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.4908 - sparse_categorical_accuracy: 0.8238 - val_loss: 0.5259 - val_sparse_categorical_accuracy: 0.8100
# Epoch 37/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.4905 - sparse_categorical_accuracy: 0.8252 - val_loss: 0.7212 - val_sparse_categorical_accuracy: 0.7201
# Epoch 38/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.4950 - sparse_categorical_accuracy: 0.8183 - val_loss: 0.5133 - val_sparse_categorical_accuracy: 0.8189
# Epoch 39/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - loss: 0.4781 - sparse_categorical_accuracy: 0.8267 - val_loss: 0.4984 - val_sparse_categorical_accuracy: 0.8239
# Epoch 40/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.4946 - sparse_categorical_accuracy: 0.8211 - val_loss: 0.5294 - val_sparse_categorical_accuracy: 0.8031
# 61/61 - 3s - 50ms/step - loss: 0.5294 - sparse_categorical_accuracy: 0.8031
# 3 끝
# Epoch 1/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 46s 338ms/step - loss: 1.8063 - sparse_categorical_accuracy: 0.3215 - val_loss: 1.3593 - val_sparse_categorical_accuracy: 0.5105
# Epoch 2/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 119ms/step - loss: 1.3957 - sparse_categorical_accuracy: 0.4705 - val_loss: 1.2003 - val_sparse_categorical_accuracy: 0.5309
# Epoch 3/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 1.1934 - sparse_categorical_accuracy: 0.5311 - val_loss: 1.0500 - val_sparse_categorical_accuracy: 0.6046
# Epoch 4/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 1.1020 - sparse_categorical_accuracy: 0.5676 - val_loss: 1.0037 - val_sparse_categorical_accuracy: 0.6208
# Epoch 5/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 1.0459 - sparse_categorical_accuracy: 0.5881 - val_loss: 0.9627 - val_sparse_categorical_accuracy: 0.6338
# Epoch 6/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.9939 - sparse_categorical_accuracy: 0.6091 - val_loss: 0.9328 - val_sparse_categorical_accuracy: 0.6472
# Epoch 7/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.9494 - sparse_categorical_accuracy: 0.6327 - val_loss: 0.8899 - val_sparse_categorical_accuracy: 0.6624
# Epoch 8/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.9228 - sparse_categorical_accuracy: 0.6472 - val_loss: 0.8859 - val_sparse_categorical_accuracy: 0.6740
# Epoch 9/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.8627 - sparse_categorical_accuracy: 0.6789 - val_loss: 0.8829 - val_sparse_categorical_accuracy: 0.6751
# Epoch 10/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - loss: 0.8529 - sparse_categorical_accuracy: 0.6759 - val_loss: 0.8039 - val_sparse_categorical_accuracy: 0.7090
# Epoch 11/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.8186 - sparse_categorical_accuracy: 0.6926 - val_loss: 0.7614 - val_sparse_categorical_accuracy: 0.7231
# Epoch 12/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.7736 - sparse_categorical_accuracy: 0.7140 - val_loss: 0.7924 - val_sparse_categorical_accuracy: 0.7170
# Epoch 13/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.7429 - sparse_categorical_accuracy: 0.7266 - val_loss: 0.7942 - val_sparse_categorical_accuracy: 0.7052
# Epoch 14/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.7149 - sparse_categorical_accuracy: 0.7354 - val_loss: 0.7153 - val_sparse_categorical_accuracy: 0.7359
# Epoch 15/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.7020 - sparse_categorical_accuracy: 0.7410 - val_loss: 0.7927 - val_sparse_categorical_accuracy: 0.7015
# Epoch 16/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.7122 - sparse_categorical_accuracy: 0.7379 - val_loss: 0.7222 - val_sparse_categorical_accuracy: 0.7204
# Epoch 17/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6941 - sparse_categorical_accuracy: 0.7409 - val_loss: 0.6484 - val_sparse_categorical_accuracy: 0.7642
# Epoch 18/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6790 - sparse_categorical_accuracy: 0.7496 - val_loss: 0.7119 - val_sparse_categorical_accuracy: 0.7406
# Epoch 19/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - loss: 0.6838 - sparse_categorical_accuracy: 0.7492 - val_loss: 0.6764 - val_sparse_categorical_accuracy: 0.7479
# Epoch 20/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - loss: 0.6509 - sparse_categorical_accuracy: 0.7620 - val_loss: 0.7030 - val_sparse_categorical_accuracy: 0.7388
# Epoch 21/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6668 - sparse_categorical_accuracy: 0.7506 - val_loss: 0.6188 - val_sparse_categorical_accuracy: 0.7695
# Epoch 22/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6255 - sparse_categorical_accuracy: 0.7697 - val_loss: 0.6815 - val_sparse_categorical_accuracy: 0.7422
# Epoch 23/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6299 - sparse_categorical_accuracy: 0.7678 - val_loss: 0.7386 - val_sparse_categorical_accuracy: 0.7193
# Epoch 24/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6188 - sparse_categorical_accuracy: 0.7749 - val_loss: 0.6359 - val_sparse_categorical_accuracy: 0.7733
# Epoch 25/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6097 - sparse_categorical_accuracy: 0.7754 - val_loss: 0.6018 - val_sparse_categorical_accuracy: 0.7816
# Epoch 26/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.6122 - sparse_categorical_accuracy: 0.7755 - val_loss: 0.5918 - val_sparse_categorical_accuracy: 0.7787
# Epoch 27/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - loss: 0.5905 - sparse_categorical_accuracy: 0.7820 - val_loss: 0.5827 - val_sparse_categorical_accuracy: 0.7858
# Epoch 28/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5797 - sparse_categorical_accuracy: 0.7860 - val_loss: 0.5704 - val_sparse_categorical_accuracy: 0.7962
# Epoch 29/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5481 - sparse_categorical_accuracy: 0.8015 - val_loss: 0.5986 - val_sparse_categorical_accuracy: 0.7851
# Epoch 30/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5699 - sparse_categorical_accuracy: 0.7908 - val_loss: 0.5843 - val_sparse_categorical_accuracy: 0.7830
# Epoch 31/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5423 - sparse_categorical_accuracy: 0.8029 - val_loss: 0.5410 - val_sparse_categorical_accuracy: 0.8077
# Epoch 32/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5439 - sparse_categorical_accuracy: 0.7987 - val_loss: 0.6017 - val_sparse_categorical_accuracy: 0.7852
# Epoch 33/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5446 - sparse_categorical_accuracy: 0.8011 - val_loss: 0.5424 - val_sparse_categorical_accuracy: 0.8011
# Epoch 34/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5317 - sparse_categorical_accuracy: 0.8057 - val_loss: 0.5575 - val_sparse_categorical_accuracy: 0.7986
# Epoch 35/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5383 - sparse_categorical_accuracy: 0.8002 - val_loss: 0.5325 - val_sparse_categorical_accuracy: 0.8124
# Epoch 36/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - loss: 0.5217 - sparse_categorical_accuracy: 0.8114 - val_loss: 0.5488 - val_sparse_categorical_accuracy: 0.8014
# Epoch 37/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5165 - sparse_categorical_accuracy: 0.8126 - val_loss: 0.5689 - val_sparse_categorical_accuracy: 0.7957
# Epoch 38/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5073 - sparse_categorical_accuracy: 0.8151 - val_loss: 0.5148 - val_sparse_categorical_accuracy: 0.8147
# Epoch 39/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5006 - sparse_categorical_accuracy: 0.8187 - val_loss: 0.5203 - val_sparse_categorical_accuracy: 0.8124
# Epoch 40/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.4943 - sparse_categorical_accuracy: 0.8207 - val_loss: 0.5069 - val_sparse_categorical_accuracy: 0.8162
# 61/61 - 3s - 50ms/step - loss: 0.5069 - sparse_categorical_accuracy: 0.8162
# 4 끝
# Epoch 1/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 324ms/step - loss: 1.7789 - sparse_categorical_accuracy: 0.3360 - val_loss: 1.4345 - val_sparse_categorical_accuracy: 0.4274
# Epoch 2/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 1.4146 - sparse_categorical_accuracy: 0.4558 - val_loss: 1.4160 - val_sparse_categorical_accuracy: 0.4392
# Epoch 3/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 1.1823 - sparse_categorical_accuracy: 0.5339 - val_loss: 1.0528 - val_sparse_categorical_accuracy: 0.5954
# Epoch 4/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 1.0839 - sparse_categorical_accuracy: 0.5657 - val_loss: 0.9771 - val_sparse_categorical_accuracy: 0.6149
# Epoch 5/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 1.0220 - sparse_categorical_accuracy: 0.5967 - val_loss: 0.9646 - val_sparse_categorical_accuracy: 0.6364
# Epoch 6/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.9748 - sparse_categorical_accuracy: 0.6188 - val_loss: 0.9386 - val_sparse_categorical_accuracy: 0.6278
# Epoch 7/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - loss: 0.9206 - sparse_categorical_accuracy: 0.6432 - val_loss: 0.8584 - val_sparse_categorical_accuracy: 0.6715
# Epoch 8/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.8739 - sparse_categorical_accuracy: 0.6620 - val_loss: 0.8783 - val_sparse_categorical_accuracy: 0.6709
# Epoch 9/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.8330 - sparse_categorical_accuracy: 0.6874 - val_loss: 0.7742 - val_sparse_categorical_accuracy: 0.7248
# Epoch 10/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.7965 - sparse_categorical_accuracy: 0.7043 - val_loss: 0.7887 - val_sparse_categorical_accuracy: 0.7081
# Epoch 11/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.7811 - sparse_categorical_accuracy: 0.7112 - val_loss: 0.7840 - val_sparse_categorical_accuracy: 0.7182
# Epoch 12/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.7683 - sparse_categorical_accuracy: 0.7208 - val_loss: 0.7170 - val_sparse_categorical_accuracy: 0.7389
# Epoch 13/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.7183 - sparse_categorical_accuracy: 0.7351 - val_loss: 0.7056 - val_sparse_categorical_accuracy: 0.7450
# Epoch 14/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.7080 - sparse_categorical_accuracy: 0.7350 - val_loss: 0.7149 - val_sparse_categorical_accuracy: 0.7394
# Epoch 15/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6852 - sparse_categorical_accuracy: 0.7486 - val_loss: 0.6800 - val_sparse_categorical_accuracy: 0.7574
# Epoch 16/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.6660 - sparse_categorical_accuracy: 0.7567 - val_loss: 0.7565 - val_sparse_categorical_accuracy: 0.7174
# Epoch 17/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.6718 - sparse_categorical_accuracy: 0.7499 - val_loss: 0.7639 - val_sparse_categorical_accuracy: 0.7143
# Epoch 18/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.6807 - sparse_categorical_accuracy: 0.7480 - val_loss: 0.6696 - val_sparse_categorical_accuracy: 0.7549
# Epoch 19/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6362 - sparse_categorical_accuracy: 0.7630 - val_loss: 0.6851 - val_sparse_categorical_accuracy: 0.7492
# Epoch 20/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6248 - sparse_categorical_accuracy: 0.7701 - val_loss: 0.6958 - val_sparse_categorical_accuracy: 0.7564
# Epoch 21/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6137 - sparse_categorical_accuracy: 0.7767 - val_loss: 0.6745 - val_sparse_categorical_accuracy: 0.7626
# Epoch 22/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.6061 - sparse_categorical_accuracy: 0.7776 - val_loss: 0.7135 - val_sparse_categorical_accuracy: 0.7350
# Epoch 23/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5818 - sparse_categorical_accuracy: 0.7897 - val_loss: 0.5857 - val_sparse_categorical_accuracy: 0.7908
# Epoch 24/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - loss: 0.5928 - sparse_categorical_accuracy: 0.7807 - val_loss: 0.5853 - val_sparse_categorical_accuracy: 0.7864
# Epoch 25/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5855 - sparse_categorical_accuracy: 0.7860 - val_loss: 0.6145 - val_sparse_categorical_accuracy: 0.7718
# Epoch 26/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5732 - sparse_categorical_accuracy: 0.7892 - val_loss: 0.6257 - val_sparse_categorical_accuracy: 0.7601
# Epoch 27/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5605 - sparse_categorical_accuracy: 0.7930 - val_loss: 0.5575 - val_sparse_categorical_accuracy: 0.7954
# Epoch 28/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5526 - sparse_categorical_accuracy: 0.8006 - val_loss: 0.6573 - val_sparse_categorical_accuracy: 0.7555
# Epoch 29/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5511 - sparse_categorical_accuracy: 0.7989 - val_loss: 0.5649 - val_sparse_categorical_accuracy: 0.8029
# Epoch 30/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5395 - sparse_categorical_accuracy: 0.8036 - val_loss: 0.5661 - val_sparse_categorical_accuracy: 0.7972
# Epoch 31/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5322 - sparse_categorical_accuracy: 0.8064 - val_loss: 0.5462 - val_sparse_categorical_accuracy: 0.8065
# Epoch 32/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5216 - sparse_categorical_accuracy: 0.8099 - val_loss: 0.5677 - val_sparse_categorical_accuracy: 0.7995
# Epoch 33/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - loss: 0.5184 - sparse_categorical_accuracy: 0.8105 - val_loss: 0.5602 - val_sparse_categorical_accuracy: 0.8005
# Epoch 34/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5071 - sparse_categorical_accuracy: 0.8152 - val_loss: 0.5991 - val_sparse_categorical_accuracy: 0.7933
# Epoch 35/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5073 - sparse_categorical_accuracy: 0.8163 - val_loss: 0.5119 - val_sparse_categorical_accuracy: 0.8133
# Epoch 36/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.4988 - sparse_categorical_accuracy: 0.8179 - val_loss: 0.5056 - val_sparse_categorical_accuracy: 0.8191
# Epoch 37/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - loss: 0.5067 - sparse_categorical_accuracy: 0.8173 - val_loss: 0.5307 - val_sparse_categorical_accuracy: 0.8148
# Epoch 38/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.4814 - sparse_categorical_accuracy: 0.8270 - val_loss: 0.5624 - val_sparse_categorical_accuracy: 0.7948
# Epoch 39/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.5069 - sparse_categorical_accuracy: 0.8170 - val_loss: 0.4919 - val_sparse_categorical_accuracy: 0.8251
# Epoch 40/40
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.4784 - sparse_categorical_accuracy: 0.8290 - val_loss: 0.5166 - val_sparse_categorical_accuracy: 0.8196
# 61/61 - 3s - 50ms/step - loss: 0.5166 - sparse_categorical_accuracy: 0.8196
# 5 끝

# %%
def plot_hist(hist):
    # history에서 loss, accuracy 값 추출
    loss = hist.history['loss']
    val_loss = hist.history['val_loss']
    sparse_categorical_accuracy = hist.history['sparse_categorical_accuracy']
    val_sparse_categorical_accuracy = hist.history['val_sparse_categorical_accuracy']

    epochs = range(1, len(loss) + 1)

    # Loss 그래프
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss, label='Training Loss')
    plt.plot(epochs, val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Accuracy 그래프
    plt.subplot(1, 2, 2)
    plt.plot(epochs, sparse_categorical_accuracy, label='Training Accuracy')
    plt.plot(epochs, val_sparse_categorical_accuracy, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
plot_hist(hist_1)
plot_hist(hist_2)
plot_hist(hist_3)
plot_hist(hist_4)
plot_hist(hist_5)

# %%
mean = np.mean([best_test_acc_1,  best_test_acc_2, best_test_acc_3, best_test_acc_4, best_test_acc_5])
std = np.std([best_test_acc_1,  best_test_acc_2, best_test_acc_3, best_test_acc_4, best_test_acc_5])

print(f"{mean*100}%, {std*100}")
# Out:
# 81.3433313369751%, 0.9733270369617779
